# %%
import pandas as pd

data = pd.read_csv("data.csv")

a1 = pd.crosstab(index = data["program"], columns = data["field_interest"])

a2 = pd.crosstab(index = data["program"], columns = data["team_responsible"])

a3 = pd.crosstab(index = data["program"], columns = data["start_work"])

a4 = pd.crosstab(index = data["program"], columns = data["design_something"])

a5 = pd.crosstab(index = data["program"], columns = data["work_partof"])

a6 = pd.crosstab(index = data["program"], columns = data["on_project"])

a7 = pd.crosstab(index = data["program"], columns = data["care_most"])

a8 = pd.crosstab(index = data["program"], columns = data["eavesdrop"])

a9 = pd.crosstab(index = data["program"], columns = data["working_with"])

print(a1, a2, a3, a4, a5, a6, a7, a8, a9)
# Out:
# field_interest              Construction  Finance  Manufacturing  Research  \
# program
# Biomedical Engineering                 1        0              8        35
# Chemical Engineering                   2        1             38        15
# Civil Engineering                     38        3              3         3
# Computer Engineering                   0        0              1         5
# Electrical Engineering                 2        6              5         8
# Environmental Engineering              9        0              1        10
# Geological Engineering                 4        2              0         2
# Management Engineering                 3       24             30         7
# Mechanical Engineering                 9        1             42        25
# Mechatronics Engineering               3        3             41        34
# Nanotechnology Engineering             0        1             11        45
# ...
